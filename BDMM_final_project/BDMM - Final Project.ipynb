# %% [markdown]
# # Big Data Modeling and Management Assigment
# ## EU Procurements Explorer Dashboard Competition
#
# For the final project we will continue to work with the european public procurement notices database to analyse contracts and money expenditure within the European Union!
#
# This time the goal is to feed data to a dashboard where we can explore the contracts in three diferent ways: per procurement code, per country and per company.
#
# #### Problem description
# Explore the code in the zip file shared with this project description.
# Spin up the dashboard and check there are no errors.
# Go to the `queries.py` and replace the exercices with actual queries following the example in `ex0_cpv_example`.  Check the dashboard charts are now working.
# Run the `Performance test`in the front page of the dashborad and try to optize the speed of your queries with the materials teached in classe like indexes and data modelling.
# Confirm you have fast queries and the dashboard is working.
# Submit the `queries.py` on moodle
#
# #### Connection details to the MongoDB database
# Each group should have received by email the credentials to connect to the group's mongo database. The same ones as homework 2.
# ```
# Connection example: mongodb://username:password@host:port
# ```
# These credentials should be added in the file `DB.py` within the project folder in the backend folder.
#
# #### Project structure
#
# * apps - All the dash dashboard code
# * assets - Web assets for the dashboard
# * backend
#     * `DB.py` - File with the database connection, this should be changed to your groups database connection
#     * `queries.py` - File where the queries will go (the one to be submited)
#     * `performance_evaluation.py` - Code used to run the performance evaluation
# * `index.py` && `app.py` - Dash basic files. To start the app run `python3 index.py` (or `docker-compose up` if familiar with docker technologies)
# * `test_insert_document.json`- example document to insert on the dashboard and measure the time taken
#
# ### Questions
# #### Procurement codes (CPV)
# 1. 5 descriptive metrics of the contracts related to the CPV, the average of:
#     1. Each CPV's division contracts average spending ('VALUE_EURO')
#     1. Each CPV's division contract count
#     1. Each CPV's division contracts average number of offers ('NUMBER_OFFERS')
#     1. Each CPV's division contracts average spending ('VALUE_EURO') with european funde ('B_EU_FUNDS')
#     1. Each CPV's division contracts average spending ('VALUE_EURO') without european funds ('B_EU_FUNDS')
# 1. The count of contracts for each CPV Division
# 1. Per CPV Division get the average spending ('VALUE_EURO') and return the highest 5 cpvs
# 1. Per CPV Division get the average spending ('VALUE_EURO') and return the lowest 5 cpvs
# 1. Per CPV Division get the average spending ('VALUE_EURO') and return the highest 5 cpvs for contracts which recieved european funds ('B_EU_FUNDS')
# 1. Per CPV Division and get the average ('VALUE_EURO') return the highest 5 cpvs for contracts which did not recieve european funds ('B_EU_FUNDS')
# 1. The highest CPV Division on average spending ('VALUE_EURO') per country ('ISO_COUNTRY_CODE')
# 1. Returns bucketed data with the contract counts of a particular cpv in a given range of values (bucket) according to spending ('VALUE_EURO')
# 1. The average time and value difference for each CPV, return the highest 5 cpvs
#
# #### Countries
# 10. 5 descriptive metrics of the contracts related to the Country, the average of:
#     1. Each Country's contracts average spending ('VALUE_EURO')
#     1. Each Country's contract count
#     1. Each Country's contracts average NUMBER_OFFERS'
#     1. Each Country's contracts average VALUE_EURO' with 'B_EU_FUNDS'
#     1. Each Country's contracts average 'VALUE_EURO' without 'B_EU_FUNDS'
# 1. The count of contracts per country ('ISO_COUNTRY_CODE')
# 1. Returns the average 'VALUE_EURO' for each country, return the highest 5 countries
# 1. Returns the average 'VALUE_EURO' for each country, return the lowest 5 countries
# 1. For each country get the sum of the respective contracts 'VALUE_EURO' which recieved european funds ('B_EU_FUNDS')
#
# #### Companies
# 15. 5 descriptive metrics of the contracts related to the Company, the average of:
#     1. Each Company's contracts average spending ('VALUE_EURO')
#     1. Each Company's contract count
#     1. Each Company's contracts average NUMBER_OFFERS'
#     1. Each Company's contracts average VALUE_EURO' with 'B_EU_FUNDS'
#     1. Each Company's contracts average 'VALUE_EURO' without 'B_EU_FUNDS'
# 1. Returns the average 'VALUE_EURO' for company ('CAE_NAME') return the highest 5 companies
# 1. Returns the average 'VALUE_EURO' for company ('CAE_NAME') return the lowest 5 companies
# 1. Returns the count of contracts for each company 'CAE_NAME', for the 15 companies with the most contracts
# 1. For each country get the highest company ('CAE_NAME') in terms of 'VALUE_EURO' sum contract spending
# 1. Returns the top 5 most frequent co-occurring companies ('CAE_NAME' and 'WIN_NAME')
#
#
# **All resulting documents should allow to perfom filters by min and max of the field year of contract, as well as for issuer country.(ISO_COUNTRY_CODE) (see example 0 for more details)**
#
# **Insert query**
# 21. On the `queries.py` there is a working function that inserts documents on the contracts database.
# If any precomputed table is generated they should be recomputed with the new data on the this insert method.
#
#
# ### Group
#
# This project assumes groups to be the same as the previous project, any copying detected by the professors will lead to a grading of zero on the project and/or other disciplinary actions!
#
#
# ### Submission
# Submit the `queries.py` file with all the queries (running on the group's own database) on moodle.
#
# Delivery date: Until **23:59 of June 19th** (as there will be no exam the due date got extended)
#
#
# ### Evaluation
#
#
# This will be 30% of the final grade.
# 1. The queries run and generate the desired visualizations.  (60%)
# 1. The speed of the query. (This will be benchmarked for all groups)   (20%)
# 1. The document insertion speed.       (This will be benchmarked for all groups)  (10%)
# 1. The simplicity of the query.  (10%)
#
# The queries will be run against each groups database. So any index or extra table created will be used.
#
# All code will go through plagiarism automated checks. Groups with the same code will undergo investigation.
#
# ### Extra information
#
# **Rounding** of numbers can be perfomend with any function, they will not be an evalution criteria.
# _Hint:_ To speed up the queries two sugestions are indexes and precomputed tables.

# %%
from pymongo import MongoClient
host="rhea.isegi.unl.pt"
port="28004"
user="GROUP_4"
password="MjIzOTc0NzI0MTAyNzAxMzg0MjcwODk0MzIwNTA4NzA2MzYxOTAw"
protocol="mongodb"
client = MongoClient(f"{protocol}://{user}:{password}@{host}:{port}")

# %%
import pandas as pd
from pymongo import MongoClient
from backend.DB import eu
from backend.DB import db

########################################################################################################################
countries = ['NO', 'HR', 'HU', 'CH', 'CZ', 'RO', 'LV', 'GR', 'UK', 'SI', 'LT',
             'ES', 'FR', 'IE', 'SE', 'NL', 'PT', 'PL', 'DK', 'MK', 'DE', 'IT',
             'BG', 'CY', 'AT', 'LU', 'BE', 'FI', 'EE', 'SK', 'MT', 'LI', 'IS']

# %%
db.extra.find_one()
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-14-3e447950baee> in <module>
# ----> 1 db.extra.find_one()
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in find_one(self, filter, *args, **kwargs)
#    1271
#    1272         cursor = self.find(filter, *args, **kwargs)
# -> 1273         for result in cursor.limit(-1):
#    1274             return result
#    1275         return None
#
# ~\Anaconda3\lib\site-packages\pymongo\cursor.py in next(self)
#    1154         if self.__empty:
#    1155             raise StopIteration
# -> 1156         if len(self.__data) or self._refresh():
#    1157             if self.__manipulate:
#    1158                 _db = self.__collection.database
#
# ~\Anaconda3\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1048
#    1049         if not self.__session:
# -> 1050             self.__session = self.__collection.database.client._ensure_session()
#    1051
#    1052         if self.__id is None:  # Query
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _ensure_session(self, session)
#    1808             # Don't make implicit sessions causally consistent. Applications
#    1809             # should always opt-in.
# -> 1810             return self.__start_session(True, causal_consistency=False)
#    1811         except (ConfigurationError, InvalidOperation):
#    1812             # Sessions not supported, or multiple users authenticated.
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in __start_session(self, implicit, **kwargs)
#    1761
#    1762         # Raises ConfigurationError if sessions are not supported.
# -> 1763         server_session = self._get_server_session()
#    1764         opts = client_session.SessionOptions(**kwargs)
#    1765         return client_session.ClientSession(
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _get_server_session(self)
#    1794     def _get_server_session(self):
#    1795         """Internal: start or resume a _ServerSession."""
# -> 1796         return self._topology.get_server_session()
#    1797
#    1798     def _return_server_session(self, server_session, lock):
#
# ~\Anaconda3\lib\site-packages\pymongo\topology.py in get_server_session(self)
#     483                             any_server_selector,
#     484                             self._settings.server_selection_timeout,
# --> 485                             None)
#     486                 elif not self._description.readable_servers:
#     487                     self._select_servers_loop(
#
# ~\Anaconda3\lib\site-packages\pymongo\topology.py in _select_servers_loop(self, selector, timeout, address)
#     207             if timeout == 0 or now > end_time:
#     208                 raise ServerSelectionTimeoutError(
# --> 209                     self._error_message(selector))
#     210
#     211             self._ensure_opened()
#
# ServerSelectionTimeoutError: rhea.isegi.unl.pt:27017: [WinError 10061] No connection could be made because the target machine actively refused it

# %%
match = {
        '$match': {
            'VALUE_EURO': {'$lt': 100000000},
            'ISO_COUNTRY_CODE': {'$in': countries},
            '$and': [{'YEAR': {'$gte': 2008}}, {'YEAR': {'$lte': 2020}}]
        }
    }

projection1 = {
        '$project': {
            '_id': {
                'YEAR': '$YEAR',
                'DT_DISPATCH': '$DT_DISPATCH',
                'CAE_NAME': '$CAE_NAME',
                'CAE_ADDRESS': '$CAE_ADDRESS',
                'CAE_TOWN': '$CAE_TOWN',
                'ISO_COUNTRY_CODE': '$ISO_COUNTRY_CODE',
                'CPV': {'$substr': ['$CPV', 0, 2]},
                'VALUE_EURO': '$VALUE_EURO',
                'B_EU_FUNDS': '$B_EU_FUNDS',
                'WIN_NAME': '$WIN_NAME',
                'AWARD_VALUE_EURO': '$AWARD_VALUE_EURO',
                'DT_AWARD': '$DT_AWARD'
            }
        }
    }

lookup1 = {
        '$lookup': {
            'from': 'iso_codes',
            'foreignField': 'alpha-2',
            'localField': '_id.ISO_COUNTRY_CODE',
            'as': 'ISOCODES'
        }
    }

projection2 = {
        '$project': {
            '_id': False,
            'isocodes': {'$arrayElemAt': ['$ISOCODES', 0]},
            'YEAR': '$YEAR',
            'DT_DISPATCH': '$DT_DISPATCH',
            'CAE_NAME': '$CAE_NAME',
            'CAE_ADDRESS': '$CAE_ADDRESS',
            'CAE_TOWN': '$CAE_TOWN',
            'ISO_COUNTRY_CODE': '$ISO_COUNTRY_CODE',
            'CPV': '$CPV',
            'VALUE_EURO': '$VALUE_EURO',
            'B_EU_FUNDS': '$B_EU_FUNDS',
            'WIN_NAME': '$WIN_NAME',
            'AWARD_VALUE_EURO': '$AWARD_VALUE_EURO',
            'DT_AWARD': '$DT_AWARD'
        }
    }

projection3 = {
        '$project': {
            'COUNTRY_NAME': '$isocodes.name',
            'YEAR': '$YEAR',
            'DT_DISPATCH': '$DT_DISPATCH',
            'CAE_NAME': '$CAE_NAME',
            'CAE_ADDRESS': '$CAE_ADDRESS',
            'CAE_TOWN': '$CAE_TOWN',
            'ISO_COUNTRY_CODE': '$ISO_COUNTRY_CODE',
            'CPV': '$CPV',
            'VALUE_EURO': '$VALUE_EURO',
            'B_EU_FUNDS': '$B_EU_FUNDS',
            'WIN_NAME': '$WIN_NAME',
            'AWARD_VALUE_EURO': '$AWARD_VALUE_EURO',
            'DT_AWARD': '$DT_AWARD'
        }
    }

lookup2 = {
        '$lookup': {
            'from': 'cpv',
            'foreignField': 'cpv_division',
            'localField': 'CPV',
            'as': 'CPV'
        }
    }

projection4 = {
        '$project': {
            '_id': False,
            'cpv': {'$arrayElemAt': ['$CPV', 0]},
            'COUNTRY_NAME': '$COUNTRY_NAME',
            'YEAR': '$YEAR',
            'DT_DISPATCH': '$DT_DISPATCH',
            'CAE_NAME': '$CAE_NAME',
            'CAE_ADDRESS': '$CAE_ADDRESS',
            'CAE_TOWN': '$CAE_TOWN',
            'ISO_COUNTRY_CODE': '$ISO_COUNTRY_CODE',
            'CPV': '$CPV',
            'VALUE_EURO': '$VALUE_EURO',
            'B_EU_FUNDS': '$B_EU_FUNDS',
            'WIN_NAME': '$WIN_NAME',
            'AWARD_VALUE_EURO': '$AWARD_VALUE_EURO',
            'DT_AWARD': '$DT_AWARD'
        }
    }

projection5 = {
        '$project': {
            'CPV_DESCRIPTION': '$cpv.cpv_division_description',
            'COUNTRY_NAME': '$COUNTRY_NAME',
            'YEAR': '$YEAR',
            'DT_DISPATCH': '$DT_DISPATCH',
            'CAE_NAME': '$CAE_NAME',
            'CAE_ADDRESS': '$CAE_ADDRESS',
            'CAE_TOWN': '$CAE_TOWN',
            'ISO_COUNTRY_CODE': '$ISO_COUNTRY_CODE',
            'CPV': '$CPV',
            'VALUE_EURO': '$VALUE_EURO',
            'B_EU_FUNDS': '$B_EU_FUNDS',
            'WIN_NAME': '$WIN_NAME',
            'AWARD_VALUE_EURO': '$AWARD_VALUE_EURO',
            'DT_AWARD': '$DT_AWARD'
        }
    }

pipeline = [match, projection1, lookup1, projection2]

list_documents = list(db.eu.aggregate(pipeline))
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-10-4b99ff254acd> in <module>
#     122 pipeline = [match, projection1, lookup1, projection2]
#     123
# --> 124 list_documents = list(db.eu.aggregate(pipeline))
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in aggregate(self, pipeline, session, **kwargs)
#    2372             https://docs.mongodb.com/manual/reference/command/aggregate
#    2373         """
# -> 2374         with self.__database.client._tmp_session(session, close=False) as s:
#    2375             return self._aggregate(_CollectionAggregationCommand,
#    2376                                    pipeline,
#
# ~\Anaconda3\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _tmp_session(self, session, close)
#    1821             return
#    1822
# -> 1823         s = self._ensure_session(session)
#    1824         if s and close:
#    1825             with s:
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _ensure_session(self, session)
#    1808             # Don't make implicit sessions causally consistent. Applications
#    1809             # should always opt-in.
# -> 1810             return self.__start_session(True, causal_consistency=False)
#    1811         except (ConfigurationError, InvalidOperation):
#    1812             # Sessions not supported, or multiple users authenticated.
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in __start_session(self, implicit, **kwargs)
#    1761
#    1762         # Raises ConfigurationError if sessions are not supported.
# -> 1763         server_session = self._get_server_session()
#    1764         opts = client_session.SessionOptions(**kwargs)
#    1765         return client_session.ClientSession(
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _get_server_session(self)
#    1794     def _get_server_session(self):
#    1795         """Internal: start or resume a _ServerSession."""
# -> 1796         return self._topology.get_server_session()
#    1797
#    1798     def _return_server_session(self, server_session, lock):
#
# ~\Anaconda3\lib\site-packages\pymongo\topology.py in get_server_session(self)
#     483                             any_server_selector,
#     484                             self._settings.server_selection_timeout,
# --> 485                             None)
#     486                 elif not self._description.readable_servers:
#     487                     self._select_servers_loop(
#
# ~\Anaconda3\lib\site-packages\pymongo\topology.py in _select_servers_loop(self, selector, timeout, address)
#     207             if timeout == 0 or now > end_time:
#     208                 raise ServerSelectionTimeoutError(
# --> 209                     self._error_message(selector))
#     210
#     211             self._ensure_opened()
#
# ServerSelectionTimeoutError: rhea.isegi.unl.pt:27017: [WinError 10061] No connection could be made because the target machine actively refused it

# %%
list_documents
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-4-f0aa1ae84902> in <module>
# ----> 1 trial(2008, 2000,countries)
#
# <ipython-input-3-14d4c0af94c0> in trial(bot_year, top_year, country_list)
#     124     pipeline = [match, projection1, lookup1, projection2]
#     125
# --> 126     list_documents = list(db.eu.aggregate(pipeline))
#     127     return list_documents
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in aggregate(self, pipeline, session, **kwargs)
#    2372             https://docs.mongodb.com/manual/reference/command/aggregate
#    2373         """
# -> 2374         with self.__database.client._tmp_session(session, close=False) as s:
#    2375             return self._aggregate(_CollectionAggregationCommand,
#    2376                                    pipeline,
#
# ~\Anaconda3\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _tmp_session(self, session, close)
#    1821             return
#    1822
# -> 1823         s = self._ensure_session(session)
#    1824         if s and close:
#    1825             with s:
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _ensure_session(self, session)
#    1808             # Don't make implicit sessions causally consistent. Applications
#    1809             # should always opt-in.
# -> 1810             return self.__start_session(True, causal_consistency=False)
#    1811         except (ConfigurationError, InvalidOperation):
#    1812             # Sessions not supported, or multiple users authenticated.
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in __start_session(self, implicit, **kwargs)
#    1761
#    1762         # Raises ConfigurationError if sessions are not supported.
# -> 1763         server_session = self._get_server_session()
#    1764         opts = client_session.SessionOptions(**kwargs)
#    1765         return client_session.ClientSession(
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _get_server_session(self)
#    1794     def _get_server_session(self):
#    1795         """Internal: start or resume a _ServerSession."""
# -> 1796         return self._topology.get_server_session()
#    1797
#    1798     def _return_server_session(self, server_session, lock):
#
# ~\Anaconda3\lib\site-packages\pymongo\topology.py in get_server_session(self)
#     483                             any_server_selector,
#     484                             self._settings.server_selection_timeout,
# --> 485                             None)
#     486                 elif not self._description.readable_servers:
#     487                     self._select_servers_loop(
#
# ~\Anaconda3\lib\site-packages\pymongo\topology.py in _select_servers_loop(self, selector, timeout, address)
#     207             if timeout == 0 or now > end_time:
#     208                 raise ServerSelectionTimeoutError(
# --> 209                     self._error_message(selector))
#     210
#     211             self._ensure_opened()
#
# ServerSelectionTimeoutError: rhea.isegi.unl.pt:27017: [WinError 10061] No connection could be made because the target machine actively refused it

# %%
# Out:
# datetime.datetime(2014, 12, 23, 0, 0)

# %%
def ex7_cpv_bar_diff(bot_year=2008, top_year=2020, country_list=countries):
    filter_ = {
            '$match': {
                '$and': [{'YEAR': {'$gte': bot_year}}, {'YEAR': {'$lte': top_year}}],
                'ISO_COUNTRY_CODE': {'$in': country_list}, 'CAE_ADDRESS': {'$ne': None}, 'CAE_TOWN': {'$ne': None}
            }
    }

    groupby_isocode_sum = {
            '$group':{
                '_id':{'iso': '$ISO_COUNTRY_CODE', 'cpv':{'$substr': ['$CPV', 0,2]}},
                'avg': {'$avg' : '$VALUE_EURO'}
            }
                
    }

    sort = { "$sort": 
            { "_id.iso": 1, 
             "avg": -1 
            } 
    }
    

    groupby_isocode_max = {    
        "$group": {
            '_id':'$_id.iso',
            "max": {"$first": "$avg"},
            "cpv": {"$first": "$_id.cpv"}
            }
    }


    lookup = {
        '$lookup': {
            'from': 'iso_codes',
            'foreignField': 'alpha-2',
            'localField': '_id',
            'as': 'ISOCODES'
        }
    }


    projection1 = {
        '$project': {
            '_id' : '$_id',
            'isocodes':{ '$arrayElemAt': ['$ISOCODES', 0]},
            'max':'$max',
            'company': '$cpv'
        }
    }

    projection2 = {
        '$project': {
            '_id': False,
            'country': '$isocodes.alpha-2',
            'max': True,
            'cpv': '$cpv'
        }
    }


    pipeline = [filter_,groupby_isocode_sum,sort,groupby_isocode_max]
    list_documents = list(db.eu.aggregate(pipeline))
    return list_documents

# %%
from datetime import datetime

def ex9_cpv_bar_diff(bot_year=2008, top_year=2020, country_list=countries):
    filter_ = {
            '$match': {
                '$and': [{'YEAR': {'$gte': bot_year}}, {'YEAR': {'$lte': top_year}}],
                'ISO_COUNTRY_CODE': {'$in': country_list}, 'CAE_ADDRESS': {'$ne': None}, 'CAE_TOWN': {'$ne': None}
            }
}

groupby_isocode_sum = {
            '$group':{
                '_id':{'iso': '$ISO_COUNTRY_CODE', 'caename':'$CAE_NAME'},
                'sum': {'$sum' : '$VALUE_EURO'}
            }
                
}

sort = { "$sort": 
            { "_id.iso": 1, 
             "sum": -1 
            } 
}
    

groupby_isocode_max = {    
    "$group": {
        '_id':'$_id.iso',
        "max": {"$first": "$sum"},
        "caename": {"$first": "$_id.caename"}
        }
}


lookup = {
    '$lookup': {
        'from': 'iso_codes',
        'foreignField': 'alpha-2',
        'localField': '_id',
        'as': 'ISOCODES'
    }
}


projection1 = {
    '$project': {
        '_id' : '$_id',
        'isocodes':{ '$arrayElemAt': ['$ISOCODES', 0]},
        'max':'$max',
        'company': '$_id.caename'
        }
    }

    projection2 = {
        '$project': {
            '_id': False,
#        'address': True,
            'country': '$isocodes.alpha-2',
            'max': True,
            'company': '$_id.caename'
        }
    }


    pipeline = [filter_,groupby_isocode_sum,sort,groupby_isocode_max]
    list_documents = list(db.eu.aggregate(pipeline))
    return list_documents

# %%
ex7_cpv_bar_diff(2008, 2020, countries)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-160-209a3c22ffd5> in <module>
# ----> 1 ex7_cpv_bar_diff(2008, 2020, countries)
#
# <ipython-input-159-59ac098a4d4d> in ex7_cpv_bar_diff(bot_year, top_year, country_list)
#      72
#      73     pipeline = [filter_,groupby_isocode_sum,sort,groupby_isocode_max]
# ---> 74     list_documents = list(db.eu.aggregate(pipeline))
#      75     return list_documents
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in aggregate(self, pipeline, session, **kwargs)
#    2378                                    session=s,
#    2379                                    explicit_session=session is not None,
# -> 2380                                    **kwargs)
#    2381
#    2382     def aggregate_raw_batches(self, pipeline, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in _aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, **kwargs)
#    2297         return self.__database.client._retryable_read(
#    2298             cmd.get_cursor, cmd.get_read_preference(session), session,
# -> 2299             retryable=not cmd._performs_write)
#    2300
#    2301     def aggregate(self, pipeline, session=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable, exhaust)
#    1462                         # not support retryable reads, raise the last error.
#    1463                         raise last_error
# -> 1464                     return func(session, server, sock_info, slave_ok)
#    1465             except ServerSelectionTimeoutError:
#    1466                 if retrying:
#
# ~\Anaconda3\lib\site-packages\pymongo\aggregation.py in get_cursor(self, session, server, sock_info, slave_ok)
#     146             session=session,
#     147             client=self._database.client,
# --> 148             user_fields=self._user_fields)
#     149
#     150         self._process_result(result, session, server, sock_info, slave_ok)
#
# ~\Anaconda3\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields)
#     611                            use_op_msg=self.op_msg_enabled,
#     612                            unacknowledged=unacknowledged,
# --> 613                            user_fields=user_fields)
#     614         except OperationFailure:
#     615             raise
#
# ~\Anaconda3\lib\site-packages\pymongo\network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields)
#     165                 helpers._check_command_response(
#     166                     response_doc, None, allowable_errors,
# --> 167                     parse_write_concern_error=parse_write_concern_error)
#     168     except Exception as exc:
#     169         if publish:
#
# ~\Anaconda3\lib\site-packages\pymongo\helpers.py in _check_command_response(response, msg, allowable_errors, parse_write_concern_error)
#     157
#     158             msg = msg or "%s"
# --> 159             raise OperationFailure(msg % errmsg, code, response)
#     160
#     161
#
# OperationFailure: Each element of the 'pipeline' array must be an object

# %%
from dateutil.parser import parse
def fix_date(date):
    dt = parse(date)
    return dt
# datetime.datetime(2010, 2, 15, 0, 0)
print(fix_date('23-DEC-14').strftime('%d/%m/%Y'))
# Out:
# 23/12/2014

# %%
from datetime import datetime
print(datetime.strptime("23-DEC-14", "%d-%b-%y"))
# Out:
# 2014-12-23 00:00:00

# %%
ex9_cpv_bar_diff(2008, 2020, countries)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-137-d38f09b987dc> in <module>
# ----> 1 ex9_cpv_bar_diff(2008, 2020, countries)
#
# <ipython-input-135-2bda0e48b11f> in ex9_cpv_bar_diff(bot_year, top_year, country_list)
#      13         '_id' : False,
#      14         'CPV_DIVISION': {'$substr': ['$CPV', 0,2]},
# ---> 15         'time_difference': {'$subtract' : [ datetime.datetime.strptime("$DT_DISPATCH", "%d-%b-%y"),
#      16                                            datetime.datetime.strptime("$DT_AWARD", "%d-%b-%y") ]},
#      17         'value_difference': {'$subtract' : [ "$AWARD_VALUE_EURO", "$VALUE_EURO" ]}
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'

# %%
import datetime
dt = int(fix_date('23-DEC-14'))
print(dt)

dt = str(pd.to_datetime(dt.replace('‑','-'),format='%Y/%m/%d'))
datetime.datetime.strptime(dt, "%Y-%m-%d %H:%M:%S")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-588018e9c6c1> in <module>
#       1 import datetime
# ----> 2 dt = int(fix_date('23-DEC-14'))
#       3 print(dt)
#       4
#       5 dt = str(pd.to_datetime(dt.replace('‑','-'),format='%Y/%m/%d'))
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'datetime.datetime'

# %%
dt.ISODate = dt.toISOString()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-8f0cca0a80b3> in <module>
# ----> 1 dt.ISODate = dt.toISOString()
#
# AttributeError: 'str' object has no attribute 'toISOString'

# %%
projection = {
    '$project':{
        '_id' : False,
        'CPV_DIVISION': {'$substr': ['$CPV', 0,2]},
        'time_difference': {"$DT_DISPATCH"}
    }
}

# %%
from datetime import datetime

def convert_date(x,y,z):
    orig_date = datetime(x,y,z)
    orig_date = str(orig_date)
    d = datetime.strptime(orig_date, '%Y-%m-%d %H:%M:%S')
    d = d.strftime('%m/%d/%y')
    return d

# %%
convert_date(2014,12,23)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-f5a7b809ebc5> in <module>
# ----> 1 convert_date(2014,12,23)
#
# <ipython-input-64-78e7502c36b4> in convert_date(x, y, z)
#       2
#       3 def convert_date(x,y,z):
# ----> 4     orig_date = datetime(x,y,z)
#       5     orig_date = str(orig_date)
#       6     d = datetime.strptime(orig_date, '%Y-%m-%d %H:%M:%S')
#
# TypeError: 'module' object is not callable

# %%
eu.find_one()
# Out:
# {'_id': ObjectId('5e58fe88e3912091230e07a2'),
#  'ID_NOTICE_CAN': 20157,
#  'TED_NOTICE_URL': 'ted.europa.eu/udl?uri=TED:NOTICE:7-2015:TEXT:EN:HTML',
#  'YEAR': 2015,
#  'ID_TYPE': 3,
#  'DT_DISPATCH': '23-DEC-14',
#  'XSD_VERSION': 'R208.S2',
#  'CANCELLED': 0,
#  'CORRECTIONS': 0,
#  'CAE_NAME': 'European Union Agency for Law Enforcement Training (CEPOL)',
#  'CAE_ADDRESS': 'Ó utca 27.',
#  'CAE_TOWN': 'Budapest',
#  'CAE_POSTAL_CODE': 1066,
#  'CAE_GPA_ANNEX': 'A1EUN',
#  'ISO_COUNTRY_CODE': 'HU',
#  'ISO_COUNTRY_CODE_GPA': 'EU',
#  'CAE_TYPE': 5,
#  'EU_INST_CODE': 'AG',
#  'MAIN_ACTIVITY': 'Public Order and Safety',
#  'B_ON_BEHALF': 'N',
#  'TYPE_OF_CONTRACT': 'S',
#  'TAL_LOCATION_NUTS': 'HU101;HU102',
#  'B_FRA_AGREEMENT': 'Y',
#  'B_FRA_CONTRACT': 'Y',
#  'CPV': 79620000,
#  'MAIN_CPV_CODE_GPA': 796,
#  'ADDITIONAL_CPVS': '79621000---79612000---79610000---79600000---79611000',
#  'B_GPA': 'N',
#  'GPA_COVERAGE': 2,
#  'LOTS_NUMBER': 0,
#  'VALUE_EURO': 400000,
#  'VALUE_EURO_FIN_1': 400000,
#  'VALUE_EURO_FIN_2': 400000,
#  'B_EU_FUNDS': 'N',
#  'TOP_TYPE': 'OPE',
#  'OUT_OF_DIRECTIVES': 0,
#  'CRIT_CODE': 'L',
#  'CRIT_PRICE_WEIGHT': 100,
#  'B_ELECTRONIC_AUCTION': 'N',
#  'NUMBER_AWARDS': 1,
#  'ID_AWARD': 6630331,
#  'INFO_UNPUBLISHED': 'N',
#  'WIN_NAME': 'Manpower Munkaerő-Szervezési Kft',
#  'WIN_ADDRESS': 'Váci street 76.',
#  'WIN_TOWN': 'Budapest',
#  'WIN_POSTAL_CODE': 1133,
#  'WIN_COUNTRY_CODE': 'HU',
#  'CONTRACT_NUMBER': 'CEPOL/CT/2014/028',
#  'NUMBER_OFFERS': 1,
#  'AWARD_EST_VALUE_EURO': 400000,
#  'AWARD_VALUE_EURO': 400000,
#  'AWARD_VALUE_EURO_FIN_1': 400000,
#  'B_SUBCONTRACTED': 'N',
#  'DT_AWARD': '20-NOV-14'}

# %%
bot_year=2008
top_year=2020
country_list=countries

# %%
from datetime import datetime

filter_ = {
            '$match': {
                '$and': [{'YEAR': {'$gte': bot_year}}, {'YEAR': {'$lte': top_year}}],
                'ISO_COUNTRY_CODE': {'$in': country_list}#, '$DT_DISPATCH': {'$ne': ""}, '$DT_AWARD': {'$ne': ""}
            }
}

projection = {
    '$project':{
        '_id' : False,
        'CPV_DIVISION': {'$substr': ['$CPV', 0,2]},
        'DT_DISPATCH':{ '$dateFromString': { 'dateString': '$DT_DISPATCH'} },
        'DT_AWARD':{ '$dateFromString': { 'dateString': '$DT_AWARD'} },
#         'time_difference': {'$subtract' : [ datetime.strptime("DT_DISPATCH", "%d-%b-%y"), 
#                                            datetime.strptime("DT_AWARD", "%d-%b-%y") ]},
        'value_difference': {'$subtract' : [ "$AWARD_VALUE_EURO", "$VALUE_EURO" ]}
    }
}

groupby_cpv_count = {
    '$group':{
        '_id': '$CPV_DIVISION',
        'time_difference': {'$avg' : '$time_difference'},
        'value_difference': {'$avg' : '$value_difference' }
    }
}

lookup = {
    '$lookup': {
        'from': 'cpv',
        'foreignField': 'cpv_division',
        'localField': '_id',
        'as': 'CPV'
    }
}

projection2 = {
    '$project': {
        '_id' : False,
        'cpv':{ '$arrayElemAt': ['$CPV', 0]},
        'time_difference':'$time_difference',
        'value_difference':'$value_difference'
    }
}

projection3 = {
    '$project': {
        'cpv': '$cpv.cpv_division_description',
        'time_difference':True,
        'value_difference':True
    }
}

sort = {
    '$sort':{
        'time_difference':-1,
        'value_difference':-1
        
    }
}

limit = {'$limit':5}


pipeline = [filter_, projection]

list_documents = list(db.eu.aggregate(pipeline))
list_documents
# Out:
# [{'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2008, 12, 31, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 10, 16, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 6, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 6, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 6, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 16, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 7, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 5, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 19, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 15, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 1, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 21, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 10, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 1, 7, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 1, 7, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 19, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 28, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 18, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 10, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 2, 4, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 1, 12, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 31, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 31, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 31, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 25, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 2, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 2, 3, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 10, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 2, 24, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 2, 27, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 2, 27, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 2, 17, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 10, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 10, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 2, 27, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 13, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 13, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 13, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 18, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 3, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 2, 27, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 18, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 2, 23, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 1, 29, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 1, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 31, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 10, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 8, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 10, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 8, 4, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 10, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 7, 31, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 10, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 7, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 8, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 8, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 8, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 7, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 8, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 7, 31, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 8, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 8, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 7, 31, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 8, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 7, 25, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 8, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 10, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 7, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 7, 31, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 7, 31, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 10, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 10, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 10, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 8, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 13, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 13, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 13, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 13, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 16, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 13, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 13, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 17, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 21, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 11, 24, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 13, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 23, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 13, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 23, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 8, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 4, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 26, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 11, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 13, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 3, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 25, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 25, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 18, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 9, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 14, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 9, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 14, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 9, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 14, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 3, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 3, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 3, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 3, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 3, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 3, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 3, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 3, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 3, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 3, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 15, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 15, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 12, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 21, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 4, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 15, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 15, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 24, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 25, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 24, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 18, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 18, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 19, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 24, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 24, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 7, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 7, 10, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 8, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 8, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 7, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 7, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 25, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 7, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 28, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 7, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 7, 3, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 7, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 7, 10, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 4, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 12, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 17, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 3, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 12, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 3, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 3, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 4, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 12, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 4, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 12, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 17, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 17, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 3, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 4, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 4, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 8, 12, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 12, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 17, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 14, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 12, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 17, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 4, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 17, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 12, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 12, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 17, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 17, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 17, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 17, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 17, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 17, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 17, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 17, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 19, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 1, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 13, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 28, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 8, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 7, 16, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 8, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 7, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 8, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 7, 16, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 9, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 7, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 22, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 26, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 22, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 22, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 22, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 22, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 22, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 22, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 7, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 22, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 22, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 21, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 21, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 21, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 21, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 27, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 19, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 25, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 13, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 28, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 10, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 10, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 13, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 7, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 15, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 10, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 15, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 10, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 15, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 10, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 20, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 10, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 8, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 22, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 22, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 28, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 22, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 25, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 22, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 25, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 18, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 25, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 26, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 18, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 22, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 26, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 26, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 22, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 26, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 22, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 17, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 30, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 17, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 3, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 3, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 13, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 29, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 13, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 16, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 21, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 10, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 21, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 10, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 21, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 10, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 21, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 10, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 21, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 10, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 21, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 10, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 10, 21, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 10, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 25, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 3, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 2, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 20, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 25, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 3, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 10, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 10, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 3, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 10, 13, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 25, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 25, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 4, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '',
# ...
#   'DT_AWARD': datetime.datetime(2009, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 30, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 8, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 7, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 3, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 3, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 16, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 3, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 5, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 6, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 7, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 3, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 3, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 3, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 3, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 3, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '33',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 15, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 21, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 25, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 4, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 8, 25, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 9, 17, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 9, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 11, 12, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 10, 16, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 2, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 10, 27, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': None,
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 1, 26, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 12, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 6, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 1, 16, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 20, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 2, 17, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 13, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 12, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 3, 18, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 1, 21, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 14, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 3, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 20, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 2, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 20, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 2, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 20, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 2, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 20, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 2, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 20, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 2, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 20, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 2, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 20, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 2, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 5, 20, 0, 0),
#   'DT_AWARD': datetime.datetime(2008, 2, 1, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 18, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 8, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 18, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 8, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 18, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 4, 8, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 6, 23, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 9, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 7, 15, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 7, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 7, 20, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 27, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 7, 20, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 27, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 7, 20, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 27, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 7, 20, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 5, 27, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 7, 28, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 6, 11, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 1, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 16, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 1, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 15, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 1, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 10, 8, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 1, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 18, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 1, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 23, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 2, 0, 0),
#   'value_difference': None},
#  {'CPV_DIVISION': '34',
#   'DT_DISPATCH': datetime.datetime(2009, 12, 16, 0, 0),
#   'DT_AWARD': datetime.datetime(2009, 11, 2, 0, 0),
#   'value_difference': None},
#  ...]

# %%
from datetime import datetime
d = datetime(2010, 2, 15)
d
# Out:
# datetime.datetime(2010, 2, 15, 0, 0)

# %%
s = d.datetime.strftime('%a %b %d %y')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-174-730981b59436> in <module>
# ----> 1 s = d.datetime.strftime('%a %b %d %y')
#
# AttributeError: 'datetime.datetime' object has no attribute 'datetime'

# %%
s
# Out:
# 'Mon Feb 15 10'

# %%
new_date = datetime.strptime(s, '%a %b %d %y')
print (new_date)
# Out:
# 2010-02-15 00:00:00
